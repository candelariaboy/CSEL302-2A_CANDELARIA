# %% [markdown]
# import libraries

# %%
import pandas as pd
import numpy as np #numerical operation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# 1

# %%
data = ('Lesson_4_student_grades_dataset.csv')
dataset = pd.read_csv(data)
statistics = dataset.describe()
x1 = dataset ['Attendance_Percentage']
x2 = dataset ['Travel_Time_to_School']
x3 = dataset ['Extracurricular_Activities']
x4 = dataset ['Hours_of_Study']
x5 = dataset ['Previous_Exam_Scores']
y = dataset  ['Grades']
print(dataset.isnull().sum())
# Out:
# Hours_of_Study                0
# Attendance_Percentage         0
# Previous_Exam_Scores          0
# Extracurricular_Activities    0
# Travel_Time_to_School         0
# Grades                        0
# dtype: int64

# %% [markdown]
# 2

# %% [markdown]
# preparing data for modeling

# %%
x = datasets.drop('Grades', axis=1)
y = datasets['Grades']

# %% [markdown]
# 3

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 4

# %%
new_data = np.array([[5,90,80,1,30]])
prediction = model.predict(new_data)

print(f"predicted Grade: {prediction[0]}")
# Out:
# predicted Grade: 41.10240424753527
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 10.Reflect- on model involves considering various factors such as data availability,model complexity and computation resource and model depends on their ability to accurate the capture the underlying pattern in to the data and contributes to the model performance and opportunities for innovate and highlighting the importance of carefully design and evaluate the models to ensure the society

# %% [markdown]
# 9.i think peer pressure and social dynamics to the students and classroom might influence student grades
